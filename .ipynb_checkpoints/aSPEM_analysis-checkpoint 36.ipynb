# %%
import pickle
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from frites import set_mpl_style
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
set_mpl_style()
import scipy.optimize
from scipy import stats
import math

# %%
path='/Users/hamzahalloway/Nextcloud/Shared/HAMZA_PhD/Data/Probant_DevAsd/RESULT_sigmo/Controles/'
from os import listdir
categories = np.sort([f for f in listdir(path)])
namesCat=[]
for cat in categories:
    namesCat.append(np.sort([f for f in listdir(path+cat)]))

# %%
namesCat[1]
# Out:
# array(['ADGO', 'ANAM', 'AUPE', 'BOBO', 'CABE', 'CEPO', 'CHRO', 'EUAU',
#        'FATH', 'FEGA', 'FLBO', 'FRCO', 'HULA', 'IRBA', 'IVBA', 'JEMO',
#        'LOBO', 'LOEP', 'MAGE', 'MAGO', 'MALA', 'MALE', 'MASO', 'MERO',
#        'MIAZ', 'MOSE', 'MYDU', 'NIVA', 'PIAL', 'PICI', 'THLA'],
#       dtype='<U4')

# %%
categories
# Out:
# array(['Ados', 'Adultes', 'Enfants'], dtype='<U7')

# %%
allFiles=[]

for nameCat,cat in zip(namesCat,categories):
    filesCat=[]
    for name in nameCat:
        files=np.sort([f for f in listdir(path+cat+'/'+name)])
        filesCat.append(files)
    allFiles.append(filesCat)

# %%
allFiles[1][9][0]#[Category:Ados,enfants, adultes ][participant's name][condition, proba]
# Out:
# 'FEGAb100.pkl'

# %%
for cat,names in zip(categories,allFiles):
    print(cat,":",len(names))
# Out:
# Ados : 45
# Adultes : 31
# Enfants : 29

# %%
allPaths=[]
for cat,names,conditions in zip(categories,namesCat,allFiles):
    catPaths=[]
    for name,namecond in zip(names,conditions):
        for condition in namecond:
            catPaths.append(path+cat+'/'+name+'/'+condition)
    allPaths.append(catPaths)

# %%
allData=[]
for cat,catPaths in zip(categories,allPaths):
    for file in catPaths:
        with open(file, 'rb') as f:
            dic = pickle.load(f)
        cols=[k for k in dic.keys()]
        vals=[v for v in dic.values()]
        vv=vals.copy()
        for i,v in enumerate(vals):
            if type(v)==list:
                if len(v)==1:
                    vv[i]=v[0]
        vals=vv
        new_dic={}
        for k,v in zip(cols,vals):
            if type(v)!=dict:
                new_dic[k]=v
        data=pd.DataFrame(dict([ (k,pd.Series(v,dtype=object)) for k,v in new_dic.items()]))
        data.drop(["old_steady_state",'old_steady_state','stop_search_misac','old_latency',"step_fit","filt"],axis=1,inplace=True)
        for col in data.columns:
            data[col].fillna(data[col].iloc[0],inplace=True)
        #Getting the probability from the name of the file
        proba=int(file[-6:-4])/100#probability
        if proba==0:
            proba=1

        data["Proba"]=[proba]*len(data)
        data["Category"]=[cat]*len(data)

        data.loc[data["bias"]==0,"Proba"]=0.5
        allData.append(data)

# %%
allData[0].columns
# Out:
# Index(['time_sup', 'start_anti', 'N_trials', 'cutoff', 'N_blocks',
#        'ramp_pursuit', 'bias', 'nb_sacc', 'observer', 'latency', 'dir_target',
#        'a_anti', 'sample_rate', 'steady_state', 'old_anti', 'after_sacc',
#        'do_whitening', 'before_sacc', 'near_sacc', 'Proba', 'Category'],
#       dtype='object')

# %%
Data=pd.concat(allData)

# %%
Data[(Data.Proba==1) & (Data.a_anti>=39.9)]
# Out:
#      time_sup  start_anti  N_trials  cutoff  N_blocks  ramp_pursuit  bias  \
# 126       280  -74.862769       150      30         1     56.054255     1
# 129       280  -42.000279       150      30         1    310.465585     1
# 53        280    7.764655       150      30         1    152.809202     1
# 114       280  -91.633917       150      30         1    119.961311     1
# 133       280  -90.760271       150      30         1    151.350215     1
# ..        ...         ...       ...     ...       ...           ...   ...
# 144       280  -32.952150       150      30         1    230.632601     1
# 94        280  -32.028231       150      30         1    451.330962     1
# 60        280   57.394514       150      30         1     41.953592     1
# 142       280 -130.484234       150      30         1    200.479360     1
# 127       280  -28.095340       150      30         1    592.986483     1
#
#      nb_sacc observer     latency  ...     a_anti  sample_rate  steady_state  \
# 126      2.0     ABBO  109.000066  ...  39.995807         1000      8.583766
# 129      4.0     ALCO  149.949791  ...  40.000000         1000      7.470562
# 53       3.0     ANBO  122.000000  ...  39.999933         1000      8.448267
# 114      2.0     ANBO  114.000001  ...  40.000000         1000      8.805400
# 133      0.0     ANBO   89.000001  ...  40.000000         1000      6.953298
# ..       ...      ...         ...  ...        ...          ...           ...
# 144      2.0     NIBO  109.000007  ...  39.993653         1000      7.180238
# 94       2.0     TOWA  133.000000  ...  39.953112         1000      9.887009
# 60       1.0     ULBA  156.000001  ...  39.999992         1000     12.404102
# 142      0.0     ULBA   98.000007  ...  39.999981         1000     10.045631
# 127      2.0     VIIB  112.999999  ...  39.952947         1000     10.166659
#
#       old_anti  after_sacc  do_whitening  before_sacc  near_sacc Proba  \
# 126  29.937435          15         False            5       True   1.0
# 129   7.817076          15         False            5      False   1.0
# 53    5.670797          15         False            5      False   1.0
# 114  18.812923          15         False            5      False   1.0
# 133  24.045695          15         False            5      False   1.0
# ..         ...         ...           ...          ...        ...   ...
# 144  27.769845          15         False            5       True   1.0
# 94   15.992308          15         False            5      False   1.0
# 60   -1.157537          15         False            5       True   1.0
# 142  50.728664          15         False            5      False   1.0
# 127  10.638370          15         False            5      False   1.0
#
#      Category
# 126      Ados
# 129      Ados
# 53       Ados
# 114      Ados
# 133      Ados
# ..        ...
# 144   Enfants
# 94    Enfants
# 60    Enfants
# 142   Enfants
# 127   Enfants
#
# [186 rows x 21 columns]

# %%
Data[Data.a_anti>=40].a_anti
# Out:
# 79     40.0
# 137    40.0
# Name: a_anti, dtype: float64

# %%
Data[Data.a_anti>=40].Proba
# Out:
# 79     1.0
# 137    0.7
# Name: Proba, dtype: float64

# %%
Data[Data.a_anti>=40].Category
# Out:
# 79        Ados
# 137    Enfants
# Name: Category, dtype: object

# %%
Data.head()
# Out:
#    time_sup  start_anti  N_trials  cutoff  N_blocks  ramp_pursuit  bias  \
# 0       280   66.717233       150      30         1     41.206341     0
# 1       280   74.818036       150      30         1    526.141661     0
# 2       280   74.995852       150      30         1     40.090382     0
# 3       280 -333.359488       150      30         1     61.560854     0
# 4       280 -161.209803       150      30         1    277.845839     0
#
#    nb_sacc observer     latency  ...     a_anti  sample_rate  steady_state  \
# 0      4.0     ABBO  306.019016  ...  13.027635         1000     10.782475
# 1      2.0     ABBO  258.000001  ...  -3.062819         1000      7.171238
# 2      2.0     ABBO  180.000003  ...   3.085418         1000      6.972899
# 3      2.0     ABBO  277.000003  ...   1.280204         1000      6.965598
# 4      2.0     ABBO  132.030118  ...   3.873728         1000      5.999747
#
#    old_anti  after_sacc  do_whitening  before_sacc  near_sacc Proba  Category
# 0  7.200720          15         False            5       True   0.5      Ados
# 1  6.051199          15         False            5       True   0.5      Ados
# 2  3.492160          15         False            5      False   0.5      Ados
# 3 -9.804654          15         False            5       True   0.5      Ados
# 4  6.993699          15         False            5      False   0.5      Ados
#
# [5 rows x 21 columns]

# %%
Data.loc[0]
# Out:
#     time_sup  start_anti  N_trials  cutoff  N_blocks  ramp_pursuit  bias  \
# 0        280   66.717233       150      30         1     41.206341     0
# 0        280 -247.997473       150      30         1     40.000037     0
# 0        280 -376.000008       150      30         1     40.000005     0
# 0        280   17.653872       150      30         1     40.008852     0
# 0        280 -174.997008       150      30         1    730.509926     0
# ..       ...         ...       ...     ...       ...           ...   ...
# 0        280 -287.795128       150      30         1    765.725665     0
# 0        280 -317.979115       150      30         1     62.435002     0
# 0        280   -1.372572       150      30         1     40.062132     0
# 0        280   58.760627       150      30         1     40.005681     0
# 0        280  -95.999669       150      30         1     40.005885     0
#
#     nb_sacc observer     latency  ...     a_anti  sample_rate  steady_state  \
# 0       4.0     ABBO  306.019016  ...  13.027635         1000     10.782475
# 0       2.0     ABBO  134.000032  ...   2.850175         1000      9.232768
# 0       4.0     ABBO  172.999988  ...   2.491812         1000     10.126836
# 0       6.0     ALCO  213.000001  ...   5.981910         1000     13.886837
# 0       4.0     ALCO  298.463642  ...   4.011597         1000      9.901946
# ..      ...      ...         ...  ...        ...          ...           ...
# 0       4.0     VIIB  244.000000  ...  -1.081691         1000      8.096455
# 0       3.0     VIIB  184.000920  ...   0.448859         1000      9.986729
# 0       6.0     VIIB  107.000001  ...   2.085748         1000     10.676072
# 0       2.0     VIIO  192.000001  ...  15.649438         1000      8.365568
# 0       2.0     VIIO  111.000287  ... -15.945630         1000     10.859196
#
#      old_anti  after_sacc  do_whitening  before_sacc  near_sacc Proba  \
# 0    7.200720          15         False            5       True   0.5
# 0    3.033586          15         False            5      False   0.5
# 0    3.076120          15         False            5      False   0.5
# 0   16.365994          15         False            5       True   0.5
# 0    4.113265          15         False            5       True   0.5
# ..        ...         ...           ...          ...        ...   ...
# 0         NaN          15         False            5       True   0.5
# 0    5.950737          15         False            5      False   0.5
# 0    6.044674          15         False            5      False   0.5
# 0   -4.489705          15         False            5      False   0.5
# 0   -6.357741          15         False            5      False   0.5
#
#     Category
# 0       Ados
# 0       Ados
# 0       Ados
# 0       Ados
# 0       Ados
# ..       ...
# 0    Enfants
# 0    Enfants
# 0    Enfants
# 0    Enfants
# 0    Enfants
#
# [310 rows x 21 columns]

# %%
Data.dropna(axis=0,inplace=True)

# %%
Data.columns
# Out:
# Index(['time_sup', 'start_anti', 'N_trials', 'cutoff', 'N_blocks',
#        'ramp_pursuit', 'bias', 'nb_sacc', 'observer', 'latency', 'dir_target',
#        'a_anti', 'sample_rate', 'steady_state', 'old_anti', 'after_sacc',
#        'do_whitening', 'before_sacc', 'near_sacc', 'Proba', 'Category'],
#       dtype='object')

# %%
plt.hist(Data[Data.bias==1].a_anti,alpha=.5,label="Biased")
plt.hist(Data[Data.bias==0].a_anti,alpha=.5,label="No bias")

plt.legend()
plt.show()

# %%
#for o in Data.observer:
#    plt.hist(Data[Data.bias==1 &( Data.observer==o)].a_anti,alpha=.5,label="Biased")
#    plt.hist(Data[Data.bias==0 &( Data.observer==o)].a_anti,alpha=.5,label="No bias")

#    plt.legend()
#    plt.show()

# %%
plt.hist(Data[Data.bias==1 ].start_anti,alpha=.5,label="Biased")
plt.hist(Data[Data.bias==0].start_anti,alpha=.5,label="No bias")

plt.legend()

# %%
#for o in Data.observer:
#    plt.hist(Data[Data.bias==1 &( Data.observer==o)].start_anti,alpha=.5,label="Biased")
#    plt.hist(Data[Data.bias==0 &( Data.observer==o)].start_anti,alpha=.5,label="No bias")
#
#    plt.legend()

# %%
Data["V_app"]=Data.a_anti*(Data.latency-Data.start_anti)/1000

# %%
def moving_avg(x, n):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[n:] - cumsum[:-n]) / float(n)

# %%
len(Data.iloc[0:150].V_app.rolling(window=5).mean().iloc[4:].values)
# Out:
# 146

# %%
plt.plot(Data.iloc[0:150].V_app)
plt.plot(Data.iloc[0:150].Proba*10)
plt.plot(Data.iloc[0:150].V_app.rolling(window=10).mean().iloc[9:],lw=2)

# %%
Data
# Out:
#      time_sup  start_anti  N_trials  cutoff  N_blocks  ramp_pursuit  bias  \
# 0         280   66.717233       150      30         1     41.206341     0
# 1         280   74.818036       150      30         1    526.141661     0
# 2         280   74.995852       150      30         1     40.090382     0
# 3         280 -333.359488       150      30         1     61.560854     0
# 4         280 -161.209803       150      30         1    277.845839     0
# ..        ...         ...       ...     ...       ...           ...   ...
# 145       280 -388.709706       150      30         1     80.236162     1
# 146       280 -557.507521       150      30         1     95.806233     1
# 147       280  -56.000634       150      30         1     40.045209     1
# 148       280 -153.943807       150      30         1     40.004612     1
# 149       280 -609.999982       150      30         1    719.013869     1
#
#      nb_sacc observer     latency  ...  sample_rate  steady_state   old_anti  \
# 0        4.0     ABBO  306.019016  ...         1000     10.782475   7.200720
# 1        2.0     ABBO  258.000001  ...         1000      7.171238   6.051199
# 2        2.0     ABBO  180.000003  ...         1000      6.972899   3.492160
# 3        2.0     ABBO  277.000003  ...         1000      6.965598  -9.804654
# 4        2.0     ABBO  132.030118  ...         1000      5.999747   6.993699
# ..       ...      ...         ...  ...          ...           ...        ...
# 145      2.0     VIIO  269.999257  ...         1000      8.939875 -25.421056
# 146      0.0     VIIO  139.999998  ...         1000     10.003059  27.269307
# 147      2.0     VIIO  121.016286  ...         1000     10.754791  -5.047367
# 148      2.0     VIIO   99.000000  ...         1000      9.844669   9.607519
# 149      1.0     VIIO  158.999999  ...         1000      7.932096  26.345593
#
#      after_sacc  do_whitening  before_sacc  near_sacc  Proba Category  \
# 0            15         False            5       True    0.5     Ados
# 1            15         False            5       True    0.5     Ados
# 2            15         False            5      False    0.5     Ados
# 3            15         False            5       True    0.5     Ados
# 4            15         False            5      False    0.5     Ados
# ..          ...           ...          ...        ...    ...      ...
# 145          15         False            5       True    0.7  Enfants
# 146          15         False            5      False    0.7  Enfants
# 147          15         False            5       True    0.7  Enfants
# 148          15         False            5       True    0.7  Enfants
# 149          15         False            5      False    0.7  Enfants
#
#         V_app
# 0    3.117536
# 1   -0.561053
# 2    0.323982
# 3    0.781385
# 4    1.135932
# ..        ...
# 145  0.715225
# 146  3.930215
# 147  0.350718
# 148  1.670502
# 149  3.818625
#
# [45869 rows x 22 columns]

# %%
np.mean(Data[Data.Proba==.7].V_app)
# Out:
# 1.1970523963575082

# %%
mu=Data.groupby(["Proba",'observer']).mean()

# %%
mu.reset_index(inplace=True)

# %%
x=np.array([0.5,0.7,0.9,1])
y=Data.groupby('Proba').mean().V_app
z=np.polyfit(x,y,1)
p = np.poly1d(z)

# %%
z
# Out:
# array([ 4.94287568, -2.2703413 ])

# %%
#Theorical plot
#Exponentiel Plot
v_target=15
P=np.linspace(0.5,1,100,endpoint=True)
sns.lineplot(data=Data,x='Proba',y='V_app',label="Data")
VV=0.08*v_target*0.5*np.log((P+1e-2)/(1-P+1e-2))+0.25
plt.plot(P,VV,label="Exponential Error Hyp",lw=3)
#Linear Plot
VV=0.2*v_target*(2*P-1)
#plt.plot(P,VV,label="Quadratic Error Hyp",lw=3)
#Fit
plt.plot(P, p(P), '-',lw=3,label='Quadratic Error Hyp')
#plt.plot(P, pp(P), '-',lw=3,label='Exponential Error Hyp')
#plt.hlines(-v_target*0.1,0,1,colors="green")
#plt.hlines(v_target*0.1,0,1,colors="green")
#plt.vlines(1/(np.exp(2)+1),-2,2,colors="green")
#plt.vlines(1/(np.exp(-2)+1),-2,2,colors="green")
plt.xlabel("Target's Probabilty going right",fontsize=30)
plt.ylabel("Anticipatory Velocity(°/s)",fontsize=30)

plt.title("Theoretical Plot of the relationship: Proba & Velocity",fontsize=30)

#sns.violinplot(data=mu,'Proba','V_app',label="Indivduals")

plt.legend()

# %%
Data["V_app"]=(Data.latency.values-Data.start_anti.values)/1000*Data.a_anti.values

# %%
#stats.shapiro(Data.V_app)

# %%
Data["Delta_v"]=15*np.array(Data.dir_target)-np.array(Data.V_app)

# %%
Data['Delta_v']
# Out:
# 0      11.882464
# 1     -14.438947
# 2     -15.323982
# 3      14.218615
# 4      13.864068
#          ...
# 145    14.284775
# 146    11.069785
# 147    14.649282
# 148    13.329498
# 149    11.181375
# Name: Delta_v, Length: 45869, dtype: float64

# %%
sns.boxplot(data=Data,x='Category',y='V_app',hue="bias")
# Out:
# <AxesSubplot: xlabel='Category', ylabel='V_app'>

# %%
md = smf.mixedlm("V_app ~Category", Data, groups=Data["bias"])
mdf=md.fit()
print(mdf.summary())
# Out:
#             Mixed Linear Model Regression Results
# =============================================================
# Model:             MixedLM  Dependent Variable:  V_app
# No. Observations:  45869    Method:              REML
# No. Groups:        2        Scale:               6.5349
# Min. group size:   14970    Log-Likelihood:      -108148.4645
# Max. group size:   30899    Converged:           Yes
# Mean group size:   22934.5
# -------------------------------------------------------------
#                     Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           0.948    0.935  1.014 0.311 -0.885  2.781
# Category[T.Adultes] 0.476    0.029 16.628 0.000  0.419  0.532
# Category[T.Enfants] 0.141    0.029  4.837 0.000  0.084  0.198
# Group Var           1.749    1.088
# =============================================================

# %%
md = smf.mixedlm("V_app ~bias", Data, groups=Data["Category"])
mdf=md.fit()
print(mdf.summary())
# Out:
#           Mixed Linear Model Regression Results
# ==========================================================
# Model:            MixedLM Dependent Variable: V_app
# No. Observations: 45869   Method:             REML
# No. Groups:       3       Scale:              6.5349
# Min. group size:  12721   Log-Likelihood:     -108147.0404
# Max. group size:  19714   Converged:          Yes
# Mean group size:  15289.7
# -----------------------------------------------------------
#              Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# -----------------------------------------------------------
# Intercept    0.268     0.142   1.885  0.059  -0.011   0.548
# bias         1.770     0.025  69.522  0.000   1.720   1.820
# Group Var    0.060     0.024
# ==========================================================

# %%
sns.boxplot(data=Data,x='Proba',y='V_app',hue="Category")
# Out:
# <AxesSubplot: xlabel='Proba', ylabel='V_app'>

# %%
sns.lineplot(data=Data,x='Proba',y='V_app',hue="Category")
# Out:
# <AxesSubplot: xlabel='Proba', ylabel='V_app'>

# %%
md = smf.mixedlm("V_app ~ Proba", Data, groups=Data["Category"],re_formula="~Proba")
mdf=md.fit(method=["lbfgs"])
print(mdf.summary())
# Out:
#            Mixed Linear Model Regression Results
# ============================================================
# Model:              MixedLM Dependent Variable: V_app
# No. Observations:   45869   Method:             REML
# No. Groups:         3       Scale:              6.2274
# Min. group size:    12721   Log-Likelihood:     -107042.2377
# Max. group size:    19714   Converged:          Yes
# Mean group size:    15289.7
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept         -2.297    0.310 -7.422 0.000 -2.904 -1.691
# Proba              5.022    0.646  7.771 0.000  3.755  6.288
# Group Var          0.281    0.239
# Group x Proba Cov -0.590    0.501
# Proba Var          1.242    1.050
# ============================================================

# %%
np.unique(Data.Proba)
# Out:
# array([0.5, 0.7, 0.9, 1. ])

# %%
Data["dir_eye"]=np.sign(Data.a_anti)

# %%
Data["Outcome"]=(Data.dir_target-Data.dir_eye)

# %%
Data.Outcome.unique()
# Out:
# array([ 0., -2.,  2., -1.,  1.])

# %%
Data.loc[Data.Outcome!=0,'Outcome']=1

# %%
np.unique(Data.Outcome)
# Out:
# array([0., 1.])

# %% [markdown]
# ## Testing the Bayesian Model on the data:

# %%
class BetaModel():
    def __init__(self,v_target,leak_factor=0.95):             
                
        self.a = 1  # the number of times this action returned a win       
        self.b = 1  # the number of times this action returned a loss
        self.n=0 # number of trials 
        self.omega=leak_factor
        self.vt=v_target #is the absolute value of the target velocity
        # pass the true probablity of the outcome|action taken              
    
    def outcome(self,q):        
        #return the boolean if 1 means that the eye and target have the same direction otherwwise the eye anticpates in
        #the wrong direction
        return stats.bernoulli.rvs(q) 
                    
    def update(self,reward):
        """ 
        reward here is the direction of the eye: 1 if it is the same as the target's direction otherwise 0
        
        """
        self.n += 1    
        
        if reward==1:
            self.a += 1
        
        else:
            self.b += 1
        
        self.a*=self.omega
        self.b*=self.omega
        
    def reset(self):
        self.n=0
        self.a=1
        self.b=1

    def sample(self):
         #return a value sampled from the beta distribution 
        return np.random.beta(self.a,self.b)
        #return np.mean(np.random.beta(self.a,self.b,10))

    def exp_velocity(self):
        p=self.a/(self.a+self.b)
        #exp Hypothesis
        return 0.2*self.vt*1/2*np.log((p)/(1-p))
    
    def quad_velocity(self):
        p=self.a/(self.a+self.b)
        #quadratic Hypothesis

        return 0.2*self.vt*(2*p-1)

# %%
v_target=15
agent=BetaModel(v_target)
mu=[]
VExp=[]
VQuad=[]
O=[]
VVQuad=[]
VVExp=[]
V_Indiv=[]
OOO=[]
MU=[]
#Probability of the target going right 
for obs in np.unique(Data.observer):
    vIndiv=[]
    P=np.unique(Data.loc[Data.observer==obs,'Proba'])
    if len(P)==4:
        for p in np.unique(Data.loc[Data.observer==obs,'Proba']):

            targetDirection=Data[(Data.Proba==p) & (Data.observer==obs)].dir_target
            eyeDirection=np.sign(Data[(Data.Proba==p) & (Data.observer==obs)].a_anti)

            res=targetDirection==eyeDirection

            O=np.array([int(r) for r in res])
            #O=targetDirection
            vv1=[]
            vv2=[]
            for o in O : 
                agent.update(o)
                vv1.append(agent.quad_velocity())
                vv2.append(agent.exp_velocity())

            #updating the model
            VQuad.append(np.mean(vv1))
            VExp.append(np.mean(vv2))

            mu.append(agent.a/(agent.a+agent.b))
            vIndiv.append(np.mean(Data[(Data.Proba==p) & (Data.observer==obs)].V_app))
        V_Indiv.append(vIndiv)  
        VVExp.append(VExp)
        VVQuad.append(VQuad)
        OOO.append(O)
        MU.append(mu)

    #print("The estimated probability of the target going right estimated by the agent is:",agent.a/(agent.a+agent.b))
    #print("The antipatory velocity of the agent is ", V[-1])
    mu=[]
    VExp=[]
    VQuad=[]
    O=[]
    
    agent.reset()

# %%
0.5 in [0.7,0.9,1]
# Out:
# False

# %%
np.mean(MU,axis=0)
# Out:
# array([0.5157927 , 0.68727145, 0.82550797, 0.93953324])

# %%
np.mean(MU,axis=0)
# Out:
# array([0.5157927 , 0.68727145, 0.82550797, 0.93953324])

# %%
np.mean(VVExp,axis=0)
# Out:
# array([0.44087263, 0.73798587, 1.69828193, 3.68746374])

# %%
np.mean(VVQuad,axis=0)
# Out:
# array([0.39782274, 0.69185799, 1.42883711, 2.30350627])

# %%
mu=Data.groupby(["Proba",'observer']).mean()

# %%
mu.reset_index(inplace=True)

# %%
mu.groupby("Proba").mean().V_app
# Out:
# Proba
# 0.5    0.246112
# 0.7    1.190954
# 0.9    1.950436
# 1.0    2.830142
# Name: V_app, dtype: float64

# %%
x=np.array([0.5,0.7,0.9,1])
y=Data.groupby('Proba').mean().V_app
z=np.polyfit(x,y,1)
p = np.poly1d(z)

# %%
#Theorical plot
#Exponentiel Plot
v_target=15

P=np.linspace(0.5,1,100,endpoint=True)
sns.lineplot(data=Data,x='Proba',y='V_app',label="Data")
#Fit
#plt.plot(P, p(P), '-',lw=3,label='Quadratic Error Hyp')
plt.plot(np.unique(Data.Proba),np.mean(VVExp,axis=0) , '-',lw=3,label='Exponential Error Hyp')
plt.plot(np.unique(Data.Proba),np.mean(VVQuad,axis=0) , '-',lw=3,label='Exponential Error Hyp')
#plt.hlines(-v_target*0.1,0,1,colors="green")
#plt.hlines(v_target*0.1,0,1,colors="green")
#plt.vlines(1/(np.exp(2)+1),-2,2,colors="green")
#plt.vlines(1/(np.exp(-2)+1),-2,2,colors="green")
plt.xlabel("$\mathbb{P}$(Target's direction=Right)",fontsize=20)
plt.ylabel("Anticipatory Velocity(°/s)",fontsize=20)

plt.title("Anticipatory velocity given $\mathbb{P}$(Target's direction=Right): Model and Individuals",fontsize=20)

plt.scatter(mu.Proba,mu.V_app,label='Individual',color='gray',alpha=0.2)

plt.legend()
plt.savefig('quadvsexp')

# %%
mu
# Out:
#      Proba observer  time_sup  start_anti  N_trials  cutoff  N_blocks  \
# 0      0.5     ABBO     280.0 -170.728564     150.0    30.0       1.0
# 1      0.5     ADGO     280.0 -129.052959     150.0    30.0       1.0
# 2      0.5     ALBR     280.0 -148.672558     150.0    30.0       1.0
# 3      0.5     ALCH     280.0 -244.885773     150.0    30.0       1.0
# 4      0.5     ALCO     280.0 -134.304301     150.0    30.0       1.0
# ..     ...      ...       ...         ...       ...     ...       ...
# 405    1.0     VIIB     280.0 -204.630071     150.0    30.0       1.0
# 406    1.0     VIIO     280.0 -187.982307     150.0    30.0       1.0
# 407    1.0     VIMI     280.0 -256.743842     150.0    30.0       1.0
# 408    1.0     WISL     280.0 -356.111783     150.0    30.0       1.0
# 409    1.0     ZEBU     280.0 -235.719711     150.0    30.0       1.0
#
#      ramp_pursuit  bias   nb_sacc  ...  sample_rate  steady_state   old_anti  \
# 0      203.898177   0.0  2.666667  ...       1000.0      7.715699   3.007603
# 1      110.012051   0.0  2.849624  ...       1000.0      9.635100   1.088777
# 2       73.803428   0.0  2.154639  ...       1000.0     14.402157   2.373334
# 3      270.097419   0.0  4.062069  ...       1000.0      7.208614   7.857172
# 4      242.951113   0.0  3.571429  ...       1000.0      9.960750  -1.486038
# ..            ...   ...       ...  ...          ...           ...        ...
# 405    198.201913   1.0  2.379630  ...       1000.0      9.355007  12.550110
# 406    112.785012   1.0  1.256881  ...       1000.0      9.600105  10.184143
# 407    155.147172   1.0  2.741935  ...       1000.0      9.876286  16.934990
# 408    132.746930   1.0  1.343137  ...       1000.0      8.157550   9.487834
# 409    147.325947   1.0  2.033333  ...       1000.0      9.480060  16.901760
#
#      after_sacc  do_whitening  before_sacc     V_app    Delta_v   dir_eye  \
# 0          15.0           0.0          5.0  0.618869  -2.140608  0.260870
# 1          15.0           0.0          5.0  0.616342  -2.533635  0.127820
# 2          15.0           0.0          5.0  0.640475  -2.341506  0.072165
# 3          15.0           0.0          5.0  0.427031  -2.806341  0.089655
# 4          15.0           0.0          5.0 -0.445287  -1.876142 -0.273810
# ..          ...           ...          ...       ...        ...       ...
# 405        15.0           0.0          5.0  2.739885  12.260115  0.851852
# 406        15.0           0.0          5.0  1.779972  13.220028  0.669725
# 407        15.0           0.0          5.0  2.953321  12.046679  0.870968
# 408        15.0           0.0          5.0  1.464868  13.535132  0.941176
# 409        15.0           0.0          5.0  3.295063  11.704937  0.888889
#
#       Outcome
# 0    0.427536
# 1    0.398496
# 2    0.319588
# 3    0.441379
# 4    0.333333
# ..        ...
# 405  0.074074
# 406  0.165138
# 407  0.064516
# 408  0.029412
# 409  0.055556
#
# [410 rows x 23 columns]

# %%
sns.lmplot(x='Proba',y="V_app",data=mu)

# %%
np.shape(np.array(VVExp))
# Out:
# (96, 4)

# %%
np.shape(np.array(VVQuad))
# Out:
# (96, 4)

# %%
Prob=np.array([0.5,0.7,0.9,1]*96)

# %%
VeloData=np.array((np.reshape(VVExp,96*4),np.reshape(VVQuad,96*4),np.reshape(V_Indiv,96*4),Prob,np.reshape(MU,96*4))).T
np.shape(VeloData)
# Out:
# (384, 5)

# %%
np.shape(V_Indiv)
# Out:
# (96, 4)

# %%
np.shape(VVQuad)
# Out:
# (96, 4)

# %%
np.shape(VVExp)
# Out:
# (96, 4)

# %%
np.shape(Prob)
# Out:
# (384,)

# %%
Velocity_Data=pd.DataFrame(VeloData,columns=["Exp","Quad","Indiv","Proba","Est_Proba"])
Velocity_Data
# Out:
#           Exp      Quad     Indiv  Proba  Est_Proba
# 0    0.596371  0.568828  0.618869    0.5   0.476839
# 1    0.583496  0.570197  1.261831    0.7   0.694889
# 2    1.544679  1.373645  2.288765    0.9   0.878025
# 3    3.487853  2.410245  2.580080    1.0   0.915598
# 4    0.632803  0.600081  0.616342    0.5   0.640638
# ..        ...       ...       ...    ...        ...
# 379  4.616028  2.645013  1.464868    1.0   0.978493
# 380 -0.339426 -0.329078  0.834802    0.5   0.419563
# 381  0.604183  0.584606  1.981843    0.7   0.684645
# 382  1.854582  1.558669  2.309099    0.9   0.799601
# 383  3.777431  2.430428  3.295063    1.0   0.986105
#
# [384 rows x 5 columns]

# %%
sns.scatterplot(x="Indiv",y="Exp",hue="Proba",data=Velocity_Data,palette="viridis",s=100,alpha=0.7)
# Out:
# <AxesSubplot: xlabel='Indiv', ylabel='Exp'>

# %%
sns.lmplot(x="Indiv",y="Exp",data=Velocity_Data)

# %%
sns.scatterplot(x="Indiv",y="Quad",hue="Proba",data=Velocity_Data,palette="viridis",alpha=0.7,s=100)
# Out:
# <AxesSubplot: xlabel='Indiv', ylabel='Quad'>

# %%
sns.lmplot(x="Indiv",y="Quad",data=Velocity_Data)

# %%
for vExp,vQuad,vObs in zip(VVExp,VVQuad,V_Indiv):
        plt.plot(np.unique(Data.Proba),vObs , '-',lw=3,label='Individual data')
        #plt.plot(np.unique(Data.Proba),vExp , '-',lw=3,label='Exponential Error Hyp')
        #plt.plot(np.unique(Data.Proba),vQuad , '-',lw=3,label='Quadratic Error Hyp')
        plt.xlabel("$\mathbb{P}$(Target's direction=Right)",fontsize=20)
        plt.ylabel("Anticipatory Velocity(°/s)",fontsize=20)
        plt.ylim(-0.5,5)
        plt.xlim(0.7,1.1)
        plt.legend()
        plt.show()

# %%
sns.violinplot(data=mu,x='Proba',y='V_app')
# Out:
# <AxesSubplot: xlabel='Proba', ylabel='V_app'>

# %%
np.mean(np.array(MU),axis=0)
# Out:
# array([0.5157927 , 0.68727145, 0.82550797, 0.93953324])

# %%
mu
# Out:
#      Proba observer  time_sup  start_anti  N_trials  cutoff  N_blocks  \
# 0      0.5     ABBO     280.0 -170.728564     150.0    30.0       1.0
# 1      0.5     ADGO     280.0 -129.052959     150.0    30.0       1.0
# 2      0.5     ALBR     280.0 -148.672558     150.0    30.0       1.0
# 3      0.5     ALCH     280.0 -244.885773     150.0    30.0       1.0
# 4      0.5     ALCO     280.0 -134.304301     150.0    30.0       1.0
# ..     ...      ...       ...         ...       ...     ...       ...
# 405    1.0     VIIB     280.0 -204.630071     150.0    30.0       1.0
# 406    1.0     VIIO     280.0 -187.982307     150.0    30.0       1.0
# 407    1.0     VIMI     280.0 -256.743842     150.0    30.0       1.0
# 408    1.0     WISL     280.0 -356.111783     150.0    30.0       1.0
# 409    1.0     ZEBU     280.0 -235.719711     150.0    30.0       1.0
#
#      ramp_pursuit  bias   nb_sacc  ...  sample_rate  steady_state   old_anti  \
# 0      203.898177   0.0  2.666667  ...       1000.0      7.715699   3.007603
# 1      110.012051   0.0  2.849624  ...       1000.0      9.635100   1.088777
# 2       73.803428   0.0  2.154639  ...       1000.0     14.402157   2.373334
# 3      270.097419   0.0  4.062069  ...       1000.0      7.208614   7.857172
# 4      242.951113   0.0  3.571429  ...       1000.0      9.960750  -1.486038
# ..            ...   ...       ...  ...          ...           ...        ...
# 405    198.201913   1.0  2.379630  ...       1000.0      9.355007  12.550110
# 406    112.785012   1.0  1.256881  ...       1000.0      9.600105  10.184143
# 407    155.147172   1.0  2.741935  ...       1000.0      9.876286  16.934990
# 408    132.746930   1.0  1.343137  ...       1000.0      8.157550   9.487834
# 409    147.325947   1.0  2.033333  ...       1000.0      9.480060  16.901760
#
#      after_sacc  do_whitening  before_sacc     V_app    Delta_v   dir_eye  \
# 0          15.0           0.0          5.0  0.618869  -2.140608  0.260870
# 1          15.0           0.0          5.0  0.616342  -2.533635  0.127820
# 2          15.0           0.0          5.0  0.640475  -2.341506  0.072165
# 3          15.0           0.0          5.0  0.427031  -2.806341  0.089655
# 4          15.0           0.0          5.0 -0.445287  -1.876142 -0.273810
# ..          ...           ...          ...       ...        ...       ...
# 405        15.0           0.0          5.0  2.739885  12.260115  0.851852
# 406        15.0           0.0          5.0  1.779972  13.220028  0.669725
# 407        15.0           0.0          5.0  2.953321  12.046679  0.870968
# 408        15.0           0.0          5.0  1.464868  13.535132  0.941176
# 409        15.0           0.0          5.0  3.295063  11.704937  0.888889
#
#       Outcome
# 0    0.427536
# 1    0.398496
# 2    0.319588
# 3    0.441379
# 4    0.333333
# ..        ...
# 405  0.074074
# 406  0.165138
# 407  0.064516
# 408  0.029412
# 409  0.055556
#
# [410 rows x 23 columns]

# %%
plt.plot(Data[Data.observer=="ABBO"].V_app[:50])
plt.plot(Data[Data.observer=="ABBO"].Proba[:50]*10)
plt.plot(Data[Data.observer=="ABBO"].dir_target[:50]*10)

# %%
plt.plot(Data[Data.observer=="ABBO"].V_app[150:300])
plt.plot(Data[Data.observer=="ABBO"].Proba[150:300]*10)
plt.plot(Data[Data.observer=="ABBO"].dir_target[150:300]*10)
plt.plot(Data[Data.observer=="ABBO"].V_app[150:300].rolling(window=20).mean().iloc[19:],lw=3)

# %%
plt.plot(Data[Data.observer=="VIIO"].V_app[:150])
plt.plot(Data[Data.observer=="VIIO"].Proba[:150]*10)
plt.plot(Data[Data.observer=="VIIO"].dir_target[:150]*10)
plt.plot(Data[Data.observer=="VIIO"].V_app[:150].rolling(20).mean().iloc[19:],lw=3)

# %%
#plt.plot(Data[Data.observer=="ADGO"].V_app[300:450])
plt.plot(Data[Data.observer=="ADGO"].Proba[300:450]*15)
plt.plot(Data[Data.observer=="ADGO"].dir_target[300:450]*15)
plt.scatter([k for k in range(18,150)],Data[Data.observer=="ADGO"].V_app[300:450])
plt.plot(Data[Data.observer=="ADGO"].V_app[300:450].rolling(window=20).mean().iloc[19:],lw=3)

# %%
len(Data[Data.observer=="ADGO"].V_app[300:450])
# Out:
# 132

# %%
plt.plot(Data[Data.observer=="VIIO"].V_app[:149])
plt.plot(Data[Data.observer=="THLA"].Proba[:149]*10)
plt.plot(Data[Data.observer=="THLA"].dir_target[:149]*15)
plt.plot(Data[Data.observer=="VIIO"].V_app[:149].rolling(window=20).mean().iloc[19:],lw=3)

# %%
plt.plot(Data[Data.observer=="ADGO"].V_app[300:450],label="Vapp")
plt.plot(Data[Data.observer=="ADGO"].Proba[300:450]*10,label="Probax10")
plt.plot(Data[Data.observer=="ADGO"].dir_target[300:450]*15,label="Target direction")
plt.plot(Data[Data.observer=="ADGO"].old_anti[300:450]*0.1,label="Old_anti")
plt.legend()

# %%
Data.columns
# Out:
# Index(['time_sup', 'start_anti', 'N_trials', 'cutoff', 'N_blocks',
#        'ramp_pursuit', 'bias', 'nb_sacc', 'observer', 'latency', 'dir_target',
#        'a_anti', 'sample_rate', 'steady_state', 'old_anti', 'after_sacc',
#        'do_whitening', 'before_sacc', 'near_sacc', 'Proba', 'Category',
#        'V_app', 'Delta_v', 'dir_eye', 'Outcome'],
#       dtype='object')

# %%
np.mean(Data[Data.observer=="THLA"].V_app[350:450])
# Out:
# 3.7342210802608222

# %%
plt.plot(Data[Data.observer=="THLA"].V_app[300:450],label="Vapp")
plt.plot(Data[Data.observer=="THLA"].Proba[300:450]*10,label="Probax10")
plt.plot(Data[Data.observer=="THLA"].dir_target[300:450]*15,label="Target direction")
plt.plot(Data[Data.observer=="THLA"].old_anti[300:450]*0.1,label="Old_anti")
plt.legend()

# %%
plt.scatter(Data[Data.observer=="THLA"].old_anti[300:450]*0.1,Data[Data.observer=="THLA"].V_app[300:450])

# %%
sns.lmplot(data=Data[Data.observer=="THLA"],x='old_anti',y='V_app')

# %%
Data
# Out:
#      time_sup  start_anti  N_trials  cutoff  N_blocks  ramp_pursuit  bias  \
# 0         280   66.717233       150      30         1     41.206341     0
# 1         280   74.818036       150      30         1    526.141661     0
# 2         280   74.995852       150      30         1     40.090382     0
# 3         280 -333.359488       150      30         1     61.560854     0
# 4         280 -161.209803       150      30         1    277.845839     0
# ..        ...         ...       ...     ...       ...           ...   ...
# 145       280 -388.709706       150      30         1     80.236162     1
# 146       280 -557.507521       150      30         1     95.806233     1
# 147       280  -56.000634       150      30         1     40.045209     1
# 148       280 -153.943807       150      30         1     40.004612     1
# 149       280 -609.999982       150      30         1    719.013869     1
#
#      nb_sacc observer     latency  ...  after_sacc  do_whitening  before_sacc  \
# 0        4.0     ABBO  306.019016  ...          15         False            5
# 1        2.0     ABBO  258.000001  ...          15         False            5
# 2        2.0     ABBO  180.000003  ...          15         False            5
# 3        2.0     ABBO  277.000003  ...          15         False            5
# 4        2.0     ABBO  132.030118  ...          15         False            5
# ..       ...      ...         ...  ...         ...           ...          ...
# 145      2.0     VIIO  269.999257  ...          15         False            5
# 146      0.0     VIIO  139.999998  ...          15         False            5
# 147      2.0     VIIO  121.016286  ...          15         False            5
# 148      2.0     VIIO   99.000000  ...          15         False            5
# 149      1.0     VIIO  158.999999  ...          15         False            5
#
#      near_sacc  Proba  Category     V_app    Delta_v dir_eye  Outcome
# 0         True    0.5      Ados  3.117536  11.882464     1.0      0.0
# 1         True    0.5      Ados -0.561053 -14.438947    -1.0      0.0
# 2        False    0.5      Ados  0.323982 -15.323982     1.0      1.0
# 3         True    0.5      Ados  0.781385  14.218615     1.0      0.0
# 4        False    0.5      Ados  1.135932  13.864068     1.0      0.0
# ..         ...    ...       ...       ...        ...     ...      ...
# 145       True    0.7   Enfants  0.715225  14.284775     1.0      0.0
# 146      False    0.7   Enfants  3.930215  11.069785     1.0      0.0
# 147       True    0.7   Enfants  0.350718  14.649282     1.0      0.0
# 148       True    0.7   Enfants  1.670502  13.329498     1.0      0.0
# 149      False    0.7   Enfants  3.818625  11.181375     1.0      0.0
#
# [45869 rows x 25 columns]

# %%
Data.loc[2].V_app.mean()
# Out:
# 0.22308043348233164

# %%
Data[Data.N_trials==150].loc[149]
# Out:
#      time_sup  start_anti  N_trials  cutoff  N_blocks  ramp_pursuit  bias  \
# 149       280  -10.270637       150      30         1    799.999995     1
# 149       280 -116.712673       150      30         1     53.978502     1
# 149       280 -376.000008       150      30         1     40.000005     1
# 149       280 -109.435305       150      30         1    794.814936     1
# 149       280 -275.314906       150      30         1     40.016792     1
# ..        ...         ...       ...     ...       ...           ...   ...
# 149       280  -50.003321       150      30         1     61.595131     1
# 149       280 -323.028189       150      30         1    242.006522     1
# 149       280 -168.001505       150      30         1     46.256247     1
# 149       280 -186.999358       150      30         1     41.734570     1
# 149       280 -609.999982       150      30         1    719.013869     1
#
#      nb_sacc observer     latency  ...  after_sacc  do_whitening  before_sacc  \
# 149      2.0     ABBO  197.000000  ...          15         False            5
# 149      2.0     ABBO  121.000093  ...          15         False            5
# 149      4.0     ABBO  172.999988  ...          15         False            5
# 149      4.0     ALCO  177.999999  ...          15         False            5
# 149      4.0     ALCO  140.999710  ...          15         False            5
# ..       ...      ...         ...  ...         ...           ...          ...
# 149      4.0     VIIB  168.999768  ...          15         False            5
# 149      2.0     VIIB  334.999999  ...          15         False            5
# 149      2.0     VIIB   78.999451  ...          15         False            5
# 149      2.0     VIIO  119.011313  ...          15         False            5
# 149      1.0     VIIO  158.999999  ...          15         False            5
#
#      near_sacc  Proba  Category     V_app    Delta_v dir_eye  Outcome
# 149       True    0.9      Ados  8.290825   6.709175     1.0      0.0
# 149      False    0.7      Ados  2.997349  12.002651     1.0      0.0
# 149      False    1.0      Ados  1.368005  13.631995     1.0      0.0
# 149       True    0.7      Ados  3.064430  11.935570     1.0      0.0
# 149      False    1.0      Ados  0.991859  14.008141     1.0      0.0
# ..         ...    ...       ...       ...        ...     ...      ...
# 149      False    0.7   Enfants  2.609310 -17.609310     1.0      1.0
# 149       True    0.9   Enfants -2.934572 -12.065428    -1.0      0.0
# 149      False    1.0   Enfants  1.329261  13.670739     1.0      0.0
# 149      False    1.0   Enfants  9.081489   5.918511     1.0      0.0
# 149      False    0.7   Enfants  3.818625  11.181375     1.0      0.0
#
# [305 rows x 25 columns]

# %%
np.unique(Data.observer)
# Out:
# array(['ABBO', 'ADGO', 'ALBR', 'ALCH', 'ALCO', 'ANAM', 'ANAR', 'ANBO',
#        'ANCH', 'ANGO', 'ANHE', 'ANIS', 'ARBA', 'AUMA', 'AUPE', 'BOBO',
#        'CAAR', 'CABE', 'CEPO', 'CHGA', 'CHMA', 'CHRO', 'DJBI', 'DOLU',
#        'EKPE', 'ELAI', 'ELMA', 'ELRO', 'ELVI', 'ENVI', 'ETGA', 'EUAU',
#        'FATH', 'FEGA', 'FLBO', 'FRCO', 'GAFI', 'GAGI', 'GALA', 'HULA',
#        'IRBA', 'IVBA', 'JEAM', 'JEFE', 'JEMO', 'JOBA', 'JUBO', 'JUPA',
#        'JUST', 'LECO', 'LEMA', 'LEPE', 'LIBA', 'LIMA', 'LOBO', 'LOEP',
#        'LORA', 'LOVO', 'MAAU', 'MABA', 'MABE', 'MACE', 'MAFE', 'MAGE',
#        'MAGO', 'MAJO', 'MALA', 'MALE', 'MANI', 'MAPA', 'MAPA2', 'MAPE',
#        'MAPI', 'MASO', 'MATR', 'MEDA', 'MERO', 'MIAZ', 'MOSE', 'MYDU',
#        'NIBO', 'NICH', 'NIFR', 'NIVA', 'NOGH', 'PAGA', 'PAMA', 'PAMA2',
#        'PIAL', 'PICI', 'ROGI', 'SATA', 'SOHE', 'TACH', 'THBO', 'THJU',
#        'THLA', 'THQU', 'TOWA', 'ULBA', 'VIIB', 'VIIO', 'VIMI', 'WISL',
#        'ZEBU'], dtype=object)

# %%
for obs in np.unique(Data.observer):
    d1=Data[(Data.observer==obs)]
    print(obs,len(Data[(Data.observer==obs)]))
# Out:
# ABBO 450
# ADGO 432
# ALBR 300
# ALCH 431
# ALCO 450
# ANAM 449
# ANAR 450
# ANBO 450
# ANCH 450
# ANGO 449
# ANHE 445
# ANIS 431
# ARBA 450
# AUMA 450
# AUPE 450
# BOBO 450
# CAAR 450
# CABE 450
# CEPO 450
# CHGA 450
# CHMA 450
# CHRO 449
# DJBI 450
# DOLU 450
# EKPE 450
# ELAI 446
# ELMA 450
# ELRO 450
# ELVI 450
# ENVI 450
# ETGA 450
# EUAU 406
# FATH 450
# FEGA 300
# FLBO 450
# FRCO 450
# GAFI 300
# GAGI 450
# GALA 450
# HULA 300
# IRBA 450
# IVBA 450
# JEAM 450
# JEFE 600
# JEMO 450
# JOBA 450
# JUBO 450
# JUPA 300
# JUST 409
# LECO 450
# LEMA 450
# LEPE 450
# LIBA 450
# LIMA 450
# LOBO 450
# LOEP 450
# LORA 450
# LOVO 450
# MAAU 450
# MABA 448
# MABE 299
# MACE 300
# MAFE 450
# MAGE 450
# MAGO 450
# MAJO 450
# MALA 450
# MALE 450
# MANI 450
# MAPA 443
# MAPA2 450
# MAPE 450
# MAPI 450
# MASO 300
# MATR 450
# MEDA 450
# MERO 450
# MIAZ 450
# MOSE 449
# MYDU 450
# NIBO 450
# NICH 450
# NIFR 450
# NIVA 450
# NOGH 450
# PAGA 450
# PAMA 450
# PAMA2 450
# PIAL 450
# PICI 450
# ROGI 450
# SATA 450
# SOHE 450
# TACH 450
# THBO 450
# THJU 450
# THLA 449
# THQU 447
# TOWA 450
# ULBA 450
# VIIB 440
# VIIO 300
# VIMI 447
# WISL 450
# ZEBU 450

# %%
Data
# Out:
#      time_sup  start_anti  N_trials  cutoff  N_blocks  ramp_pursuit  bias  \
# 0         280   66.717233       150      30         1     41.206341     0
# 1         280   74.818036       150      30         1    526.141661     0
# 2         280   74.995852       150      30         1     40.090382     0
# 3         280 -333.359488       150      30         1     61.560854     0
# 4         280 -161.209803       150      30         1    277.845839     0
# ..        ...         ...       ...     ...       ...           ...   ...
# 145       280 -388.709706       150      30         1     80.236162     1
# 146       280 -557.507521       150      30         1     95.806233     1
# 147       280  -56.000634       150      30         1     40.045209     1
# 148       280 -153.943807       150      30         1     40.004612     1
# 149       280 -609.999982       150      30         1    719.013869     1
#
#      nb_sacc observer     latency  ...  after_sacc  do_whitening  before_sacc  \
# 0        4.0     ABBO  306.019016  ...          15         False            5
# 1        2.0     ABBO  258.000001  ...          15         False            5
# 2        2.0     ABBO  180.000003  ...          15         False            5
# 3        2.0     ABBO  277.000003  ...          15         False            5
# 4        2.0     ABBO  132.030118  ...          15         False            5
# ..       ...      ...         ...  ...         ...           ...          ...
# 145      2.0     VIIO  269.999257  ...          15         False            5
# 146      0.0     VIIO  139.999998  ...          15         False            5
# 147      2.0     VIIO  121.016286  ...          15         False            5
# 148      2.0     VIIO   99.000000  ...          15         False            5
# 149      1.0     VIIO  158.999999  ...          15         False            5
#
#      near_sacc  Proba  Category     V_app    Delta_v dir_eye  Outcome
# 0         True    0.5      Ados  3.117536  11.882464     1.0      0.0
# 1         True    0.5      Ados -0.561053 -14.438947    -1.0      0.0
# 2        False    0.5      Ados  0.323982 -15.323982     1.0      1.0
# 3         True    0.5      Ados  0.781385  14.218615     1.0      0.0
# 4        False    0.5      Ados  1.135932  13.864068     1.0      0.0
# ..         ...    ...       ...       ...        ...     ...      ...
# 145       True    0.7   Enfants  0.715225  14.284775     1.0      0.0
# 146      False    0.7   Enfants  3.930215  11.069785     1.0      0.0
# 147       True    0.7   Enfants  0.350718  14.649282     1.0      0.0
# 148       True    0.7   Enfants  1.670502  13.329498     1.0      0.0
# 149      False    0.7   Enfants  3.818625  11.181375     1.0      0.0
#
# [45869 rows x 25 columns]

# %%
import math

# %%
print(math.nan)
# Out:
# nan

# %%
uu=np.array([math.nan]*2+[1,2])

# %%
uu
# Out:
# array([nan, nan,  1.,  2.])

# %%
np.nanmean(uu)
# Out:
# 1.5

# %%
Data[Data.observer=="FEGA"].V_app
# Out:
# 0      0.325575
# 1      4.738834
# 2      4.728434
# 3      1.368557
# 4     -0.601809
#          ...
# 145    3.487034
# 146    3.702324
# 147    3.711548
# 148    1.383660
# 149    2.253429
# Name: V_app, Length: 300, dtype: float64

# %%
f='/Users/hamzahalloway/Nextcloud/Shared/HAMZA_PhD/Data/Probant_DevAsd/DATA/Controles/Ados/ABBO/ABBOa90.asc'

# %%
import re
from datetime import datetime
with open(f,'r') as file:
    lines = file.readlines()
inp = [line.encode('ascii', 'ignore').decode() for line in lines]

# %%
inp
# Out:
# ['** CONVERTED FROM /Users/PsychoMac/Downloads/ABBOa90.edf using edfapi 4.0 MacOS X Jul  7 2014 on Wed Jan  9 16:08:53 2019\n',
#  '** DATE: Thu Jan 26 01:30:40 2017\n',
#  '** TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED\n',
#  '** VERSION: EYELINK II 1\n',
#  '** SOURCE: EYELINK CL\n',
#  '** EYELINK II CL v5.01 Jan 16 2014\n',
#  '** CAMERA: Eyelink GL Version 1.2 Sensor=AI7\n',
#  '** SERIAL NUMBER: CLG-BAF38\n',
#  '** CAMERA_CONFIG: BAF38200.SCD\n',
#  '**\n',
#  '\n',
#  'MSG\t7461752 !CAL \n',
#  '>>>>>>> CALIBRATION (HV9,P-CR) FOR LEFT: <<<<<<<<<\n',
#  'MSG\t7461752 !CAL Calibration points:  \n',
#  'MSG\t7461752 !CAL -26.8, -15.0         0,    339   \n',
#  'MSG\t7461752 !CAL -27.0, -32.9         0,  -2303   \n',
#  'MSG\t7461752 !CAL -26.5,  5.8         0,   2818   \n',
#  'MSG\t7461752 !CAL  11.2, -15.2     -3693,    339   \n',
#  'MSG\t7461752 !CAL -63.6, -15.5      3693,    339   \n',
#  'MSG\t7461752 !CAL  10.8, -32.7     -3814,  -2303   \n',
#  'MSG\t7461752 !CAL -63.7, -32.4      3814,  -2303   \n',
#  'MSG\t7461752 !CAL  9.8,  2.1     -3580,   2818   \n',
#  'MSG\t7461752 !CAL -63.0,  1.1      3580,   2818   \n',
#  'MSG\t7461752 !CAL eye check box: (L,R,T,B)\n',
#  '\t  -71    19   -37    10\n',
#  'MSG\t7461752 !CAL href cal range: (L,R,T,B)\n',
#  '\t-5721  5721 -3583  4098\n',
#  'MSG\t7461752 !CAL Cal coeff:(X=a+bx+cy+dxx+eyy,Y=f+gx+goaly+ixx+jyy)\n',
#  '   0.00030511 -98.753  1.1469  0.043731  0.022199 \n',
#  '   338.71 -0.55321  134.4  0.037215 -0.724\n',
#  'MSG\t7461752 !CAL Prenormalize: offx, offy = -26.82 -14.969\n',
#  'MSG\t7461752 !CAL Quadrant center: centx, centy = \n',
#  '   0.00030492  338.71\n',
#  'MSG\t7461752 !CAL Corner correction:\n',
#  '  -1.5369e-05, -6.4289e-06 \n',
#  '  -1.3688e-05,  1.6648e-05 \n',
#  '   6.9176e-06, -4.8864e-05 \n',
#  '  -1.0513e-05,  5.8538e-05 \n',
#  'MSG\t7461752 !CAL Gains: cx:98.334 lx:99.055 rx:95.402\n',
#  'MSG\t7461752 !CAL Gains: cy:123.965 ty:142.817 by:65.734\n',
#  'MSG\t7461752 !CAL Resolution (upd) at screen center: X=2.7, Y=2.1\n',
#  'MSG\t7461752 !CAL Gain Change Proportion: X: 0.038 Y: 1.173\n',
#  'MSG\t7461752 !CAL Gain Ratio (Gy/Gx) = 1.261\n',
#  'MSG\t7461752 !CAL Cross-Gain Ratios: X=0.012, Y=0.004 \n',
#  'MSG\t7461752 !CAL Quadrant fixup[1] = 0.025,0.031\n',
#  'MSG\t7461752 !CAL Quadrant fixup[0] = 0.029,0.012\n',
#  'MSG\t7461752 !CAL Quadrant fixup[3] = 0.019,0.105\n',
#  'MSG\t7461752 !CAL Quadrant fixup[2] = 0.012,0.086\n',
#  'MSG\t7461752 !CAL PCR gain ratio(x,y) = 2.194, 1.872\n',
#  'MSG\t7461752 !CAL CR gain match(x,y) = 1.010, 1.010\n',
#  'MSG\t7461752 !CAL Slip rotation correction OFF\n',
#  'MSG\t7461752 !CAL \n',
#  '>>>>>>> CALIBRATION (HV9,P-CR) FOR RIGHT: <<<<<<<<<\n',
#  'MSG\t7461752 !CAL Calibration points:  \n',
#  'MSG\t7461752 !CAL -27.4, -18.7         0,    339   \n',
#  'MSG\t7461752 !CAL -27.7, -35.5         0,  -2303   \n',
#  'MSG\t7461752 !CAL -27.1,  2.1         0,   2818   \n',
#  'MSG\t7461752 !CAL  7.7, -16.4     -3693,    339   \n',
#  'MSG\t7461752 !CAL -59.8, -17.7      3693,    339   \n',
#  'MSG\t7461752 !CAL  7.2, -35.0     -3814,  -2303   \n',
#  'MSG\t7461752 !CAL -59.9, -34.4      3814,  -2303   \n',
#  'MSG\t7461752 !CAL  7.5, -0.6     -3580,   2818   \n',
#  'MSG\t7461752 !CAL -59.4, -0.9      3580,   2818   \n',
#  'MSG\t7461752 !CAL eye check box: (L,R,T,B)\n',
#  '\t  -67    14   -39     6\n',
#  'MSG\t7461752 !CAL href cal range: (L,R,T,B)\n',
#  '\t-5721  5721 -3583  4098\n',
#  'MSG\t7461752 !CAL Cal coeff:(X=a+bx+cy+dxx+eyy,Y=f+gx+goaly+ixx+jyy)\n',
#  '   0.00030511 -109.73  1.9264  0.12705 -0.012317 \n',
#  '   338.71 -2.2054  140.1 -0.1932 -0.98416\n',
#  'MSG\t7461752 !CAL Prenormalize: offx, offy = -27.408 -18.659\n',
#  'MSG\t7461752 !CAL Quadrant center: centx, centy = \n',
#  '   0.00030491  338.71\n',
#  'MSG\t7461752 !CAL Corner correction:\n',
#  '  -1.285e-05,  2.1218e-05 \n',
#  '  -1.4978e-05,  5.9232e-06 \n',
#  '  -9.8033e-06, -8.4274e-05 \n',
#  '  -1.2663e-05,  5.706e-05 \n',
#  'MSG\t7461752 !CAL Gains: cx:100.498 lx:109.976 rx:99.417\n',
#  'MSG\t7461752 !CAL Gains: cy:123.403 ty:157.868 by:46.069\n',
#  'MSG\t7461752 !CAL Resolution (upd) at screen center: X=2.6, Y=2.1\n',
#  'MSG\t7461752 !CAL Gain Change Proportion: X: 0.106 Y: 2.427\n',
#  'MSG\t7461752 !CAL Gain Ratio (Gy/Gx) = 1.228\n',
#  'MSG\t7461752 !CAL Cross-Gain Ratios: X=0.017, Y=0.017 \n',
#  'MSG\t7461752 !CAL Quadrant fixup[1] = 0.029,0.012\n',
#  'MSG\t7461752 !CAL Quadrant fixup[0] = 0.026,0.043\n',
#  'MSG\t7461752 !CAL Quadrant fixup[3] = 0.021,0.095\n',
#  'MSG\t7461752 !CAL Quadrant fixup[2] = 0.015,0.130\n',
#  'MSG\t7461752 !CAL PCR gain ratio(x,y) = 2.043, 1.948\n',
#  'MSG\t7461752 !CAL CR gain match(x,y) = 1.010, 1.010\n',
#  'MSG\t7461752 !CAL Slip rotation correction OFF\n',
#  'MSG\t7461753 !CAL CALIBRATION HV9 LR LEFT    GOOD \n',
#  'MSG\t7461753 !CAL CALIBRATION HV9 LR RIGHT   GOOD \n',
#  'INPUT\t7463418\t127\n',
#  'MSG\t7478457 !CAL VALIDATION HV9 LR LEFT  GOOD ERROR 0.46 avg. 0.90 max  OFFSET 0.30 deg. -16.2,-1.1 pix.\n',
#  'MSG\t7478457 !CAL VALIDATION HV9 LR RIGHT GOOD ERROR 0.45 avg. 0.89 max  OFFSET 0.24 deg. -13.0,2.0 pix.\n',
#  'MSG\t7478457 VALIDATE LR POINT 0  LEFT  at 840,525  OFFSET 0.41 deg.  -21.8,4.2 pix.\n',
#  'MSG\t7478457 VALIDATE LR 4POINT 0 RIGHT  at 840,525  OFFSET 0.56 deg.  -20.0,18.9 pix.\n',
#  'MSG\t7478457 VALIDATE LR POINT 1  LEFT  at 840,89  OFFSET 0.50 deg.  -26.6,-4.9 pix.\n',
#  'MSG\t7478457 VALIDATE LR 4POINT 1 RIGHT  at 840,89  OFFSET 0.49 deg.  -15.7,-17.9 pix.\n',
#  'MSG\t7478457 VALIDATE LR POINT 2  LEFT  at 840,960  OFFSET 0.75 deg.  1.8,-34.2 pix.\n',
#  'MSG\t7478457 VALIDATE LR 4POINT 2 RIGHT  at 840,960  OFFSET 0.37 deg.  -13.7,-12.1 pix.\n',
#  'MSG\t7478457 VALIDATE LR POINT 3  LEFT  at 101,525  OFFSET 0.42 deg.  -2.9,19.2 pix.\n',
#  'MSG\t7478457 VALIDATE LR 4POINT 3 RIGHT  at 101,525  OFFSET 0.39 deg.  -4.5,-17.3 pix.\n',
#  'MSG\t7478457 VALIDATE LR POINT 4  LEFT  at 1578,525  OFFSET 0.60 deg.  -26.1,16.1 pix.\n',
#  'MSG\t7478457 VALIDATE LR 4POINT 4 RIGHT  at 1578,525  OFFSET 0.22 deg.  -9.1,-6.3 pix.\n',
#  'MSG\t7478457 VALIDATE LR POINT 5  LEFT  at 189,141  OFFSET 0.90 deg.  -33.5,-29.9 pix.\n',
#  'MSG\t7478457 VALIDATE LR 4POINT 5 RIGHT  at 189,141  OFFSET 0.18 deg.  -9.7,-1.7 pix.\n',
#  'MSG\t7478457 VALIDATE LR POINT 6  LEFT  at 1490,141  OFFSET 0.62 deg.  -23.5,-19.8 pix.\n',
#  'MSG\t7478457 VALIDATE LR 4POINT 6 RIGHT  at 1490,141  OFFSET 0.66 deg.  -7.5,-29.4 pix.\n',
#  'MSG\t7478457 VALIDATE LR POINT 7  LEFT  at 189,908  OFFSET 0.16 deg.  -8.0,2.4 pix.\n',
#  'MSG\t7478457 VALIDATE LR 4POINT 7 RIGHT  at 189,908  OFFSET 0.89 deg.  -4.5,40.5 pix.\n',
#  'MSG\t7478457 VALIDATE LR POINT 8  LEFT  at 1490,908  OFFSET 0.07 deg.  3.5,-1.0 pix.\n',
#  'MSG\t7478457 VALIDATE LR 4POINT 8 RIGHT  at 1490,908  OFFSET 0.14 deg.  -2.5,-6.1 pix.\n',
#  'INPUT\t7485648\t127\n',
#  'MSG\t7490489 DRIFTCORRECT LR LEFT  at 840,525  OFFSET 0.60 deg.  -10.4,-25.3 pix.\n',
#  'MSG\t7490489 DRIFTCORRECT LR RIGHT at 840,525  OFFSET 0.33 deg.  -15.7,5.8 pix.\n',
#  'MSG\t7490533 Trialinfo: 1 0 3\n',
#  'INPUT\t7490585\t127\n',
#  'MSG\t7490640 RECCFG CR 1000 2 1 LR\n',
#  'MSG\t7490640 ELCLCFG BTABLER\n',
#  'MSG\t7490640 GAZE_COORDS 0.00 0.00 1679.00 1049.00\n',
#  'MSG\t7490640 THRESHOLDS L 128 243  R 130 243\n',
#  'MSG\t7490640 ELCL_WINDOW_SIZES 160 160 0 0\n',
#  'MSG\t7490640 ELCL_PROC CENTROID (3)\n',
#  'MSG\t7490640 ELCL_PCR_PARAM 5 3.0\n',
#  'MSG\t7490641 !MODE RECORD CR 1000 2 1 LR\n',
#  'START\t7490644 \tLEFT\tRIGHT\tSAMPLES\tEVENTS\n',
#  'PRESCALER\t1\n',
#  'VPRESCALER\t1\n',
#  'PUPIL\tAREA\n',
#  'EVENTS\tGAZE\tLEFT\tRIGHT\tRATE\t1000.00\tTRACKING\tCR\tFILTER\t2\n',
#  'SAMPLES\tGAZE\tLEFT\tRIGHT\tRATE\t1000.00\tTRACKING\tCR\tFILTER\t2\tINPUT\n',
#  'INPUT\t7490644\t127\n',
#  '7490644\t  827.2\t  504.1\t 1372.0\t  826.8\t  541.8\t 1243.0\t  127.0\t.....\n',
#  '7490645\t  827.4\t  504.0\t 1371.0\t  826.6\t  542.0\t 1242.0\t  127.0\t.....\n',
#  '7490646\t  827.7\t  504.1\t 1370.0\t  826.4\t  542.2\t 1242.0\t  127.0\t.....\n',
#  '7490647\t  828.0\t  503.7\t 1369.0\t  826.0\t  542.1\t 1243.0\t  127.0\t.....\n',
#  '7490648\t  828.0\t  503.3\t 1368.0\t  825.8\t  542.0\t 1244.0\t  127.0\t.....\n',
#  '7490649\t  827.9\t  503.0\t 1368.0\t  825.5\t  541.8\t 1245.0\t  127.0\t.....\n',
#  '7490650\t  828.0\t  503.0\t 1368.0\t  825.4\t  541.5\t 1244.0\t  127.0\t.....\n',
#  '7491499\t  835.7\t  502.4\t 1774.0\t  828.3\t  541.9\t 1611.0\t  127.0\t.....\n',
#  '7491500\t  835.8\t  502.4\t 1775.0\t  828.4\t  542.0\t 1613.0\t  127.0\t.....\n',
#  '7491501\t  835.9\t  502.5\t 1775.0\t  828.6\t  542.1\t 1614.0\t  127.0\t.....\n',
#  '7491502\t  835.9\t  502.4\t 1776.0\t  828.8\t  542.1\t 1615.0\t  127.0\t.....\n',
#  '7491503\t  835.9\t  502.3\t 1777.0\t  829.1\t  542.1\t 1616.0\t  127.0\t.....\n',
#  '7491504\t  836.0\t  502.1\t 1777.0\t  829.1\t  542.1\t 1616.0\t  127.0\t.....\n',
#  '7491505\t  836.0\t  501.9\t 1779.0\t  829.3\t  542.1\t 1617.0\t  127.0\t.....\n',
#  ...]

# %%
inp_first = [re.split(r'\s', s)[0] for s in inp]

# %%
is_raw = [bool(re.match('^[0-9]', line)) for line in inp_first]
#is_raw2 = [re.match(r'^\d', s) is not None for s in inp_first]

# %% [markdown]
# ## Transforming .asc file into dataframe

# %%
def from_header(header, field):
    pattern = r"\*\* {}\s*: (.*)".format(re.escape(field))
    matches = [re.findall(pattern, line) for line in header]
    matches = [match for match in matches if match]
    return matches[0][0] if matches else None

    





def process_events(rows, blocks, colnames):
    # If no data, create empty dataframe w/ all cols and types
    if len(rows) == 0:
        rows = ["", ""]
        blocks = []
    # Parse data, dropping useless first column
    if len(rows) == 1:
        rows.append("")
    colnames = ['type'] + colnames # first col is event type, which we drop later
    coltypes = get_coltypes(colnames)
    df = pd.read_csv(io.StringIO('\n'.join(rows)), delimiter='\s+', header=None, names=colnames, na_values='.', index_col=False)
    df = df.iloc[:, 1:] # drop the first column
    # Move eye column to end & make factor, append block numbers to beginning of data frame
    if 'eye' in colnames:
        df = df.iloc[:, [1] + list(range(2, df.shape[1])) + [0]]
        df['eye'] = pd.Categorical(df['eye'], categories=["L", "R"], ordered=False)
    df.insert(loc=0, column='block', value=blocks)
    return df




def process_saccades(saccades, blocks, info):
    sacc_df = process_events(saccades, blocks, get_sacc_header(info))
    # Set amplitudes for any saccades missing start/end coords to NAs because they're wonky
    ampl_cols = [col for col in sacc_df.columns if re.search(r'ampl\d*$', col)]
    partial = sacc_df['sxp'].isna() | sacc_df['exp'].isna()
    if any(partial):
        sacc_df.loc[partial, ampl_cols] = pd.NA
    return sacc_df


def process_fixations(fixations, blocks, info):
    return process_events(fixations, blocks, get_fix_header(info))


def process_blinks(blinks, blocks):
    return process_events(blinks, blocks, ['eye', 'stime', 'etime', 'dur'])


def process_messages(msgs, blocks):
    # Process messages from tracker
    msg_mat = [msg.split(' ', 1) for msg in msgs]
    msg_mat = [[msg[0][4:], msg[1]] for msg in msg_mat]
    msg_df = pd.DataFrame(msg_mat, columns=['time', 'text'])
    msg_df['time'] = pd.to_numeric(msg_df['time'])
    # Append block numbers to beginning of data frame
    msg_df.insert(0, 'block', blocks)
    return msg_df


def process_input(input_data, blocks):
    return process_events(input_data, blocks, ['time', 'value'])


def process_buttons(button, blocks):
    return process_events(button, blocks, ['time', 'button', 'state'])

# %%
def get_model(header):
    version_str = from_header(header, "VERSION")
    version_str2 = [x for x in header if re.search("\\*\\* EYELINK II", x)]
    if version_str is None:
        model = "Unknown"
        ver_num = "Unknown"
    elif version_str != 'EYELINK II 1':
        model = "EyeLink I"
        ver_num = re.search(r'(\d+.\d+)', version_str).group(1)
    else:
        ver_num = re.search(r'v(\d+.\d+)', version_str2[0]).group(1)
        model = ('EyeLink II' if float(ver_num) < 2.4 else
                 'EyeLink 1000' if float(ver_num) < 5 else
                 'EyeLink 1000 Plus' if float(ver_num) < 6 else
                 'EyeLink Portable Duo')
    return [model, ver_num]

# %%
def get_resolution(nonsample):
    res = [None, None]
    for pattern in ["DISPLAY_COORDS", "GAZE_COORDS", "RESOLUTION"]:
        display_xy = [s for s in nonsample if pattern in s]
        if len(display_xy) == 0:
            continue
        display_xy = re.sub(f".* {pattern}\\D+(.*)", "\\1", display_xy[0])
        try:
            display_xy = [int(float(s)) for s in display_xy.split()]
        except ValueError:
            continue
        res = [display_xy[2] - display_xy[0] + 1, display_xy[3] - display_xy[1] + 1]
        break
    return res

# %%
def get_mount(mount_str):
    # Older EyeLink 1000s may be missing "R" in table mount names, we add one if needed
    if re.search("TABLE$", mount_str):
        mount_str = mount_str + "R"
    
    mounts = {
        "MTABLER": "Desktop / Monocular / Head Stabilized",
        "BTABLER": "Desktop / Binocular / Head Stabilized",
        "RTABLER": "Desktop / Monocular / Remote",
        "RBTABLER": "Desktop / Binocular / Remote",
        "AMTABLER": "Arm Mount / Monocular / Head Stabilized",
        "ARTABLER": "Arm Mount / Monocular / Remote",
        "TOWER": "Tower Mount / Monocular / Head Stabilized",
        "BTOWER": "Tower Mount / Binocular / Head Stabilized",
        "MPRIM": "Primate Mount / Monocular / Head Stabilized",
        "BPRIM": "Primate Mount / Binocular / Head Stabilized",
        "MLRR": "Long-Range Mount / Monocular / Head Stabilized",
        "BLRR": "Long-Range Mount / Binocular / Head Stabilized"
    }
    
    return mounts[mount_str] if mount_str in mounts else None

# %%
def get_info(nonsample, firstcol):
    header = [f for f in nonsample if f.startswith ("**")]
    info = {}
    
    # Get date/time of recording from file
    datetime.strptime(from_header(header, "DATE"), "%a %b %d %H:%M:%S %Y")
    # Get tracker model/version info
    version_info = get_model(header)
    info["model"] = version_info[0]
    info["version"] = version_info[1]

    # Get tracker mount info
    elclcfg = [line for line in nonsample if "ELCLCFG" in line]
    if len(elclcfg) > 0:
        info["mount"] = get_mount(re.findall(r"ELCLCFG\s+(.*)", elclcfg[0])[0])

    # Get display size from file
    screen_res = get_resolution(nonsample)
    info["screen.x"] = screen_res[0]
    info["screen.y"] = screen_res[1]

    #Get pupil size data type (area or diameter)
    pupil_config = [line for i,line in enumerate(nonsample) if firstcol[i] == "PUPIL"]
    if len(pupil_config) > 0:
        info["pupil.dtype"] = pupil_config[-1].split()[1]

    # Find the samples and events config lines in the non-sample input, get data types
    events_config = [line for i,line in enumerate(nonsample) if firstcol[i] == "EVENTS"]
    samples_config = [line for i,line in enumerate(nonsample) if firstcol[i]== "SAMPLES"]
    
    # Find the samples and events config lines in the non-sample input, get data types
    events_config = [line for i,line in enumerate(nonsample) if firstcol[i] == "EVENTS"]
    samples_config = [line for i,line in enumerate(nonsample) if firstcol[i] == "SAMPLES"]
    if len(events_config) > 0:
        info["event.dtype"] = events_config[-1].split()[1]
    if len(samples_config) > 0:
        info["sample.dtype"] = samples_config[-1].split()[1]
    
   
        
    
    # Get last config line in file (preferring sample config) and extract remaining info
    config = events_config + samples_config[-1:]
    config = config[-1] if len(config) > 0 else ""
    if config:
        info["sample.rate"] = float(re.findall(r"RATE\s+([0-9]+\.[0-9]+)", config)[0]) if "RATE" in config else None
        info["tracking"] = "\tTRACKING" in config
        info["cr"] = "\tCR" in config
        info["filter.level"] = int(re.findall(r"FILTER\s+([0-9]+)", config)[0]) if "FILTER" in config else None
        info["velocity"] = "\tVEL" in config
        info["resolution"] = "\tRES" in config
        info["htarg"] = "\tHTARG" in config
        info["input"] = "\tINPUT" in config
        info["buttons"] = "\tBUTTONS" in config
        info["left"] = "\tLEFT" in config
        info["right"] = "\tRIGHT" in config
        info["mono"] = not(info["right"] & info["left"])



    return info

# %%
nonsample=[line for line, raw in zip(inp, is_raw) if not raw]

# %%
firstcol=[line for line, raw in zip(inp_first, is_raw) if not raw]

# %%
header = [f for f in nonsample if f.startswith ("**")]

# %%
header
# Out:
# ['** CONVERTED FROM /Users/PsychoMac/Downloads/ABBOa90.edf using edfapi 4.0 MacOS X Jul  7 2014 on Wed Jan  9 16:08:53 2019\n',
#  '** DATE: Thu Jan 26 01:30:40 2017\n',
#  '** TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED\n',
#  '** VERSION: EYELINK II 1\n',
#  '** SOURCE: EYELINK CL\n',
#  '** EYELINK II CL v5.01 Jan 16 2014\n',
#  '** CAMERA: Eyelink GL Version 1.2 Sensor=AI7\n',
#  '** SERIAL NUMBER: CLG-BAF38\n',
#  '** CAMERA_CONFIG: BAF38200.SCD\n',
#  '**\n']

# %%
version_str = from_header(header, "VERSION")
version_str2 = [x for x in header if re.search("\\*\\* EYELINK II", x)]

# %%
version_str
# Out:
# 'EYELINK II 1'

# %%
version_str2
# Out:
# ['** EYELINK II CL v5.01 Jan 16 2014\n']

# %%
from_header(header, "DATE")
# Out:
# 'Thu Jan 26 01:30:40 2017'

# %%
ver_num = re.search(r'(\d+.\d+)', version_str2[0])

# %%
ver_num.group(1)
# Out:
# '5.01'

# %%
get_resolution(nonsample)
# Out:
# [1680, 1050]

# %%
#Get pupil size data type (area or diameter)
pupil_config = [line for i,line in enumerate(nonsample) if nonsample == "PUPIL"]
if len(pupil_config) > 0:
    pad = pupil_config[-1].split()[1]

# Find the samples and events config lines in the non-sample input, get data types
events_config = [line for i,line in enumerate(nonsample) if firstcol[i] == "EVENTS"]
samples_config = [line for i,line in enumerate(nonsample) if firstcol[i]== "SAMPLES"]
config = events_config + samples_config[-1:]
# Find the samples and events config lines in the non-sample input, get data types
events_config = [line for i,line in enumerate(nonsample) if firstcol[i] == "EVENTS"]
samples_config = [line for i,line in enumerate(nonsample) if firstcol[i] == "SAMPLES"]
if len(events_config) > 0:
    ed = events_config[-1].split()[1]
if len(samples_config) > 0:
    sd= samples_config[-1].split()[1]

# %%
pupil_config = [line for i,line in enumerate(nonsample) if firstcol[i] == "PUPIL"]

# %%
info=get_info(nonsample,firstcol)

# %%
info
# Out:
# {'model': 'EyeLink 1000 Plus',
#  'version': '5.01',
#  'mount': 'Desktop / Binocular / Head Stabilized',
#  'screen.x': 1680,
#  'screen.y': 1050,
#  'pupil.dtype': 'AREA',
#  'event.dtype': 'GAZE',
#  'sample.dtype': 'GAZE',
#  'sample.rate': 1000.0,
#  'tracking': True,
#  'cr': True,
#  'filter.level': 2,
#  'velocity': False,
#  'resolution': False,
#  'htarg': False,
#  'input': True,
#  'buttons': False,
#  'left': True,
#  'right': True,
#  'mono': False}

# %%
starts = [i for i,x in enumerate(inp_first) if x == "START"]
# Do some extra processing/sanitizing if there's HTARG info in the file
if info['htarg']:
    inp, info = handle_htarg(inp, info, is_raw)

# Find blocks and mark lines between block ENDs and next block STARTs
dividers = starts + [len(inp)]
block = np.cumsum([x == "START" for x in inp_first])
block = block.astype(float)

for i in range(1, len(dividers)):
    start = dividers[i-1]
    end = dividers[i]
    endline = [j for j, x in enumerate(inp_first[start:end]) if x == "END"]
    if endline and endline[-1] < end-start:
         block[endline[0]+start:end] += 0.5
block[:dividers[0]+1] += 0.5

# %%
import pandas as pd
import numpy as np
import re
import warnings
import io

def process_raw(raw, blocks, info):
    if len(raw) == 0:
        # If no sample data in file, create empty raw DataFrame w/ all applicable columns
        raw = ["", ""]
        blocks = pd.Series([], dtype=int)
        colnames = get_raw_header(info)
        coltypes = get_coltypes(colnames, float_time=False)
    else:
        # Determine if timestamps stored as floats (edf2asc option -ftime, useful for 2000 Hz)
        float_time = is_float(re.split(r'\s+', raw[0])[0])
        # Generate column names and types based in info in header
        colnames = get_raw_header(info)
        coltypes = get_coltypes(colnames, float_time)
        # Discard any rows with too many or too few columns (usually rows where eye is missing)
        row_length = [len(re.split(r'\t', r)) for r in raw]
        med_length = np.median(row_length)
        raw = [r for r, l in zip(raw, row_length) if l == med_length]
        blocks = blocks[row_length == med_length]
        # Verify that generated columns match up with actual maximum row length
        length_diff = med_length - len(colnames)
        if length_diff > 0:
            warnings.warn("Unknown columns in raw data. Assuming first one is time, please check the others")
            colnames = ["time"] + [f"X{i+1}" for i in range(med_length-1)]
            coltypes = "i" + "?"*(med_length-1)
    # Process raw sample data using pandas
    if len(raw) == 1:
        raw.append("")
   
    raw_df = pd.read_csv(io.StringIO("".join(raw)), sep='\t', header=None, names=colnames, na_values=np.nan, low_memory=False)

    if info["tracking"] and not info["cr"]:
        raw_df = raw_df.drop(columns=["cr.info"]) # Drop CR column when not actually used
    # Append block numbers to beginning of DataFrame
    raw_df.insert(0, "block", blocks)
    # Replace missing pupil data (zeros) with NaNs
    if "X1" not in raw_df.columns:
        if info["mono"]:
            raw_df.loc[raw_df["ps"] == 0, "ps"] = np.nan
        else:
            raw_df.loc[raw_df["psl"] == 0, "psl"] = np.nan
            raw_df.loc[raw_df["psr"] == 0, "psr"] = np.nan
    return raw_df

# %%
def get_raw_header(info):
    eyev = ["xp", "yp", "ps"]
    
    if not info["mono"]:
        eyev = [f"{e}{s}" for s in ["l", "r"] for e in eyev]
    
    if info["velocity"]:
        if info["mono"]:
            eyev += ["xv", "yv"]
        else:
            eyev += [f"{e}{s}" for s in ["vl", "vr"] for e in ["x", "y"]]
    
    if info["resolution"]:
        eyev += ["xr", "yr"]
    
    if info["input"]:
        eyev += ["input"]
    
    if info["buttons"]:
        eyev += ["buttons"]
    
    if info["tracking"]:
        eyev += ["cr.info"]
    
    if info["htarg"]:
        eyev += ["tx", "ty", "td", "remote.info"]
    
    return ["time"] + eyev

    

def get_event_header(info, xy_cols):
    base = ["eye", "stime", "etime", "dur"]
    
    if info["event.dtype"] == "HREF":
        xy_cols = [f"href.{xy}" for xy in xy_cols] + xy_cols
        
    if info["resolution"]:
        xy_cols += ["xr", "yr"]
        
    return base + xy_cols
    

def get_sacc_header(info):
    return get_event_header(info, ["sxp", "syp", "exp", "eyp", "ampl", "pv"])
    

def get_fix_header(info):
    return get_event_header(info, ["axp", "ayp", "aps"])
    
    
def is_float(string):
    return bool(re.search("\\.", string))


def get_coltypes(colnames, float_time=True):
    chr_cols=["type", "eye", "cr.info", "remote.info"]
    int_cols=["button", "state", "value"]
    time_cols=["time", "stime", "etime", "dur"]
    if not float_time:
        int_cols += time_cols
    
    coltypes = ['str' if col in chr_cols else 'int64' if col in int_cols else 'float64' for col in colnames]
    
    return coltypes

# %%
raw,blocks=[line for line, raw in zip(inp, is_raw) if raw],block[is_raw]

# %%
blocks
# Out:
# array([  1.,   1.,   1., ..., 150., 150., 150.])

# %%
process_raw(raw,blocks,info)
# Out:
#         block     time      xpl      ypl     psl      xpr      ypr     psr  \
# 0         1.0  7490644    827.2    504.1  1372.0    826.8    541.8  1243.0
# 1         1.0  7490645    827.4    504.0  1371.0    826.6    542.0  1242.0
# 2         1.0  7490646    827.7    504.1  1370.0    826.4    542.2  1242.0
# 3         1.0  7490647    828.0    503.7  1369.0    826.0    542.1  1243.0
# 4         1.0  7490648    828.0    503.3  1368.0    825.8    542.0  1244.0
# ...       ...      ...      ...      ...     ...      ...      ...     ...
# 280003  150.0  7918950   1124.9    430.3  3098.0   1054.3    479.3  2820.0
# 280004  150.0  7918951   1125.1    430.5  3098.0   1055.2    479.5  2820.0
# 280005  150.0  7918952   1125.1    430.3  3098.0   1055.5    479.5  2820.0
# 280006  150.0  7918953   1125.2    430.0  3098.0   1055.8    479.5  2821.0
# 280007  150.0  7918954   1125.6    429.6  3098.0   1055.8    479.4  2821.0
#
#         input cr.info
# 0       127.0   .....
# 1       127.0   .....
# 2       127.0   .....
# 3       127.0   .....
# 4       127.0   .....
# ...       ...     ...
# 280003  127.0   .....
# 280004  127.0   .....
# 280005  127.0   .....
# 280006  127.0   .....
# 280007  127.0   .....
#
# [280008 rows x 10 columns]

# %%
get_raw_header(info)
# Out:
# ['time', 'xpl', 'ypl', 'psl', 'xpr', 'ypr', 'psr', 'input', 'cr.info']

# %%
colnames = get_raw_header(info)
coltypes = get_coltypes(colnames, float_time=False)
coltypes
# Out:
# ['int64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'str']

# %%
colnames
# Out:
# ['time', 'xpl', 'ypl', 'psl', 'xpr', 'ypr', 'psr', 'input', 'cr.info']

# %%
#pd.read_csv(raw,usecols=colnames,)

# %%
#pd.DataFrame(raw,columns=colnames,dtype=F)

# %%
raw_df = pd.read_csv(io.StringIO("".join(raw)), sep='\t', header=None, names=colnames, na_values=".", low_memory=False)

# %%
is_sacc = np.array(inp_first) == "ESACC"

# %%
process_saccades(np.array(inp)[is_sacc], np.array(block)[is_sacc], info)
# Out:
#      block    stime    etime  dur     sxp    syp     exp    eyp  ampl   pv eye
# 0      1.0  7492095  7492130   36   835.8  537.1   918.9  529.6   1.6  235   R
# 1      1.0  7492094  7492141   48   863.4  480.6   983.3  484.2  2.29  284   L
# 2      1.0  7492293  7492324   32  1028.0  483.2  1016.0  483.2  0.23  140   L
# 3      1.0  7492293  7492325   33   999.8  529.9   989.1  530.7   0.2  162   R
# 4      2.0  7494420  7494453   34   856.0  488.0   819.9  503.0  0.77  204   R
# ..     ...      ...      ...  ...     ...    ...     ...    ...   ...  ...  ..
# 800  150.0  7917293  7917332   40   725.9  485.0   809.1  523.1  1.81  213   R
# 801  150.0  7917500  7917530   31   902.1  459.9   876.2  442.6  0.63  134   L
# 802  150.0  7917500  7917531   32   835.7  527.1   811.5  514.1  0.55  150   R
# 803  150.0  7918324  7918620  297   939.1  404.9  1056.8  555.8  4.06  617   L
# 804  150.0  7918331  7918626  296   850.9  468.7   957.8  624.6  4.05  529   R
#
# [805 rows x 11 columns]

# %%
get_sacc_header(info)
# Out:
# ['eye', 'stime', 'etime', 'dur', 'sxp', 'syp', 'exp', 'eyp', 'ampl', 'pv']

# %%
sacc_df = process_events(np.array(inp)[is_sacc], np.array(block)[is_sacc], get_sacc_header(info))

# %%
sacc_df
# Out:
#      block    stime    etime  dur     sxp    syp     exp    eyp  ampl   pv eye
# 0      1.0  7492095  7492130   36   835.8  537.1   918.9  529.6  1.60  235   R
# 1      1.0  7492094  7492141   48   863.4  480.6   983.3  484.2  2.29  284   L
# 2      1.0  7492293  7492324   32  1028.0  483.2  1016.0  483.2  0.23  140   L
# 3      1.0  7492293  7492325   33   999.8  529.9   989.1  530.7  0.20  162   R
# 4      2.0  7494420  7494453   34   856.0  488.0   819.9  503.0  0.77  204   R
# ..     ...      ...      ...  ...     ...    ...     ...    ...   ...  ...  ..
# 800  150.0  7917293  7917332   40   725.9  485.0   809.1  523.1  1.81  213   R
# 801  150.0  7917500  7917530   31   902.1  459.9   876.2  442.6  0.63  134   L
# 802  150.0  7917500  7917531   32   835.7  527.1   811.5  514.1  0.55  150   R
# 803  150.0  7918324  7918620  297   939.1  404.9  1056.8  555.8  4.06  617   L
# 804  150.0  7918331  7918626  296   850.9  468.7   957.8  624.6  4.05  529   R
#
# [805 rows x 11 columns]

# %%
is_sacc
# Out:
# array([False, False, False, ..., False, False, False])

# %%
is_sacc
# Out:
# array([False, False, False, ..., False, False, False])
